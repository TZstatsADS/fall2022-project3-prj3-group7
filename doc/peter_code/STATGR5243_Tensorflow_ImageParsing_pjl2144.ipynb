# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import os
import matplotlib.pyplot as plt
from PIL import Image
import statsmodels.api as sm
#!pip install tenso
import tensorflow_datasets as tfds
import torch
import cv2
#import torchvision.transforms as transforms
noisy = '/Users/peter/Downloads/train_data/noisy_labels.csv'
clean = '/Users/peter/Downloads/train_data/clean_labels.csv'

# %%
clean_labels = pd.read_csv(clean,header = None).rename(columns={0:'label'})
noisy_labels = pd.read_csv(noisy,header=None).rename(columns={0:'label'}) #fixed zero index issue

# %%
direx = '/Users/peter/Downloads/train_data/'
list_of_labels = list(noisy_labels['label'])
ttest = tf.keras.preprocessing.image_dataset_from_directory(direx, labels = list_of_labels,label_mode = 'int' ,color_mode = 'rgb' ,shuffle = False)
# Out:
# Found 50000 files belonging to 1 classes.

# %%
list_of_labels_2 = list(clean_labels['label'])
plt.figure(figsize=(10,10))
for images, labels in ttest.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title("noisy: " + str(list_of_labels[i])+" true:  "+ str(list_of_labels_2[i]))
        print(labels[i])
        plt.axis("off")
plt.show()
# Out:
# tf.Tensor(3, shape=(), dtype=int32)
# tf.Tensor(5, shape=(), dtype=int32)
# tf.Tensor(9, shape=(), dtype=int32)
# tf.Tensor(6, shape=(), dtype=int32)
# tf.Tensor(5, shape=(), dtype=int32)
# tf.Tensor(8, shape=(), dtype=int32)
# tf.Tensor(2, shape=(), dtype=int32)
# tf.Tensor(4, shape=(), dtype=int32)
# tf.Tensor(2, shape=(), dtype=int32)

# %%
#Preprocessing the images
import matplotlib.pyplot as plt
plt.plot(list_of_labels,list_of_labels_2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-b959e084999f> in <module>
#       1 #Preprocessing the images
#       2 import matplotlib.pyplot as plt
# ----> 3 plt.plot(list_of_labels,list_of_labels_2)
#       4 plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
# ...

# %%
len(list_of_labels_2)
# Out:
# 10000
